# %%
import pandas as pd

# %%
d=pd.read_csv('D:\president_heights.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plp

# %%
marks=[60,81,52,63,44,75]
sub=['Telugu','Hindi','java','English','python','c']
plp.bar(sub,marks)
plp.title("Subjects Marks")
plp.xlabel("marks")
plp.ylabel("sub")
plp.ylim(50,100)
plp.show()

# %%
sns.barplot(x='name',y='height(cm)',data=d)
# Out:
# <AxesSubplot:xlabel='name', ylabel='height(cm)'>

# %%
sns.barplot(x='name',y='height(cm)',data=d)
plp.xticks(rotation=90)
plp.figure(figsize=(15,5))

# %%
import numpy as np

# %%
sns.barplot(x='name',y='height(cm)',data=d)
plp.title("President Heights")
plp.ylim(100,200)
plp.xticks(rotation=90)
plp.figure(figsize=(15,5))

# %%
sns.barplot(x='order',y='height(cm)',data=d,color='red')
plp.title("President Heights")
plp.ylim(175,180) #height range from 175 to 180
plp.xticks(rotation=90)
plp.figure(figsize=(15,5))

# %%
#Basic steps for creating data set

data=pd.Series([1.0,1.5,1.75,2.0],index=['a','b','c','d'])

# %%
data[1]
# Out:
# 1.5

# %%
data['b']
# Out:
# 1.5

# %%
'a' in data
# Out:
# True

# %%
'f' in data
# Out:
# False

# %%
data.keys()
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
data.values
# Out:
# array([1.  , 1.5 , 1.75, 2.  ])

# %%
data.items
# Out:
# <bound method Series.items of a    1.00
# b    1.50
# c    1.75
# d    2.00
# dtype: float64>

# %%
l=list(data.items())
l
# Out:
# [('a', 1.0), ('b', 1.5), ('c', 1.75), ('d', 2.0)]

# %%
l.append(('e',2.5))
l
# Out:
# [('a', 1.0), ('b', 1.5), ('c', 1.75), ('d', 2.0), ('e', 2.5), ('e', 2.5)]

# %%
data['f']=2.5
data
# Out:
# a    1.00
# b    1.50
# c    1.75
# d    2.00
# f    2.50
# dtype: float64

# %%
data[2:]
# Out:
# c    1.75
# d    2.00
# f    2.50
# dtype: float64

# %%
data[1:].values
# Out:
# array([1.5 , 1.75, 2.  , 2.5 ])

# %%
data[(data>1.5)&(data<2.5)]
# Out:
# c    1.75
# d    2.00
# dtype: float64

# %%
area=({'chennai':46,'Tirpati':26,'Kerala':166,'Delhi':48})
area
# Out:
# {'chennai': 46, 'Tirpati': 26, 'Kerala': 166, 'Delhi': 48}

# %%
area.keys()
# Out:
# dict_keys(['chennai', 'Tirpati', 'Kerala', 'Delhi'])

# %%
pop=area=pd.Series({'chennai':46,'Tirpati':26,'Kerala':166,'Delhi':48})
pop
# Out:
# chennai     46
# Tirpati     26
# Kerala     166
# Delhi       48
# dtype: int64

# %%
data=pd.DataFrame({'area':area,'pop':pop})
data
# Out:
#          area  pop
# chennai    46   46
# Tirpati    26   26
# Kerala    166  166
# Delhi      48   48

# %%
data['density']=data['pop']+data['area']

# %%
data
# Out:
#          area  pop  density
# chennai    46   46       90
# Tirpati    26   26       90
# Kerala    166  166       90
# Delhi      48   48       90

# %%
data.values
# Out:
# array([[ 46,  46,  90],
#        [ 26,  26,  90],
#        [166, 166,  90],
#        [ 48,  48,  90]], dtype=int64)

# %%
data.keys()
# Out:
# Index(['area', 'pop', 'density'], dtype='object')

# %%
data.values[2]
# Out:
# array([166, 166,  90], dtype=int64)

# %%
data.values[:,0]
# Out:
# array([ 46,  26, 166,  48], dtype=int64)

# %%
d
# Out:
#     order                    name  height(cm)
# 0       1       George Washington         189
# 1       2              John Adams         170
# 2       3        Thomas Jefferson         189
# 3       4           James Madison         163
# 4       5            James Monroe         183
# 5       6       John Quincy Adams         171
# 6       7          Andrew Jackson         185
# 7       8        Martin Van Buren         168
# 8       9  William Henry Harrison         173
# 9      10              John Tyler         183
# 10     11           James K. Polk         173
# 11     12          Zachary Taylor         173
# 12     13        Millard Fillmore         175
# 13     14         Franklin Pierce         178
# 14     15          James Buchanan         183
# 15     16         Abraham Lincoln         193
# 16     17          Andrew Johnson         178
# 17     18        Ulysses S. Grant         173
# 18     19     Rutherford B. Hayes         174
# ...

# %%
d.iloc[4]
# Out:
# order                    5
# name          James Monroe
# height(cm)             183
# Name: 4, dtype: object

# %%
data.iloc[0]
# Out:
# area       46
# pop        46
# density    90
# Name: chennai, dtype: int64

# %%
data.iloc[0,2]=90

# %%
data.iloc[0]['density']=100

# %%
data
# Out:
#          area  pop  density
# chennai    46   46      100
# Tirpati    26   26       90
# Kerala    166  166       90
# Delhi      48   48       90

# %%
data[data.density>80]
# Out:
#          area  pop  density
# chennai    46   46      100
# Tirpati    26   26       90
# Kerala    166  166       90
# Delhi      48   48       90

# %%
data.iloc[1]['density']=38
data
# Out:
#          area  pop  density
# chennai    46   46      100
# Tirpati    26   26       38
# Kerala    166  166       90
# Delhi      48   48       90

# %%
data1=pd.Series([1,np.nan,2,None,3],index=['a','b','c','d','e'])

# %%
data1
# Out:
# a    1.0
# b    NaN
# c    2.0
# d    NaN
# e    3.0
# dtype: float64

# %%
data1.fillna(1.5)
# Out:
# a    1.0
# b    1.5
# c    2.0
# d    1.5
# e    3.0
# dtype: float64

# %%
data1.fillna(method='ffill')
# Out:
# a    1.0
# b    1.0
# c    2.0
# d    2.0
# e    3.0
# dtype: float64

# %%
data1.fillna(method='bfill')
# Out:
# a    1.0
# b    2.0
# c    2.0
# d    3.0
# e    3.0
# dtype: float64
